# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 760

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | kodiak
# Processing Record 2 of the Set 1 | cape town
# Processing Record 3 of the Set 1 | asau
# Processing Record 4 of the Set 1 | katobu
# Processing Record 5 of the Set 1 | bluff
# Processing Record 6 of the Set 1 | stornoway
# Processing Record 7 of the Set 1 | nome
# Processing Record 8 of the Set 1 | huazolotitlan
# City not found. Skipping...
# Processing Record 9 of the Set 1 | sitio novo do tocantins
# Processing Record 10 of the Set 1 | busselton
# Processing Record 11 of the Set 1 | kalmunai
# Processing Record 12 of the Set 1 | adrar
# Processing Record 13 of the Set 1 | mount gambier
# Processing Record 14 of the Set 1 | valparaiso
# City not found. Skipping...
# Processing Record 15 of the Set 1 | boyolangu
# Processing Record 16 of the Set 1 | koplik
# Processing Record 17 of the Set 1 | axim
# Processing Record 18 of the Set 1 | ballina
# Processing Record 19 of the Set 1 | hasaki
# Processing Record 20 of the Set 1 | karratha
# Processing Record 21 of the Set 1 | kapaa
# Processing Record 22 of the Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 23 of the Set 1 | punta arenas
# Processing Record 24 of the Set 1 | san policarpo
# Processing Record 25 of the Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of the Set 1 | ginda
# Processing Record 27 of the Set 1 | vaini
# Processing Record 28 of the Set 1 | yellowknife
# Processing Record 29 of the Set 1 | mataura
# Processing Record 30 of the Set 1 | uglovskoye
# City not found. Skipping...
# Processing Record 31 of the Set 1 | nikolskoye
# City not found. Skipping...
# Processing Record 32 of the Set 1 | kruisfontein
# Processing Record 33 of the Set 1 | crystal beach
# Processing Record 34 of the Set 1 | carnarvon
# Processing Record 35 of the Set 1 | hilo
# Processing Record 36 of the Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of the Set 1 | berlevag
# Processing Record 38 of the Set 1 | albany
# Processing Record 39 of the Set 1 | bambous virieux
# City not found. Skipping...
# Processing Record 40 of the Set 1 | rikitea
# Processing Record 41 of the Set 1 | sitka
# Processing Record 42 of the Set 1 | nanortalik
# Processing Record 43 of the Set 1 | abilene
# Processing Record 44 of the Set 1 | fonte boa
# Processing Record 45 of the Set 1 | east london
# Processing Record 46 of the Set 1 | listvyanskiy
# City not found. Skipping...
# Processing Record 47 of the Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of the Set 1 | grand baie
# City not found. Skipping...
# Processing Record 49 of the Set 1 | isabela
# Processing Record 50 of the Set 1 | dedougou
# Processing Record 1 of the Set 2 | new norfolk
# Processing Record 2 of the Set 2 | kavaratti
# Processing Record 3 of the Set 2 | itarema
# Processing Record 4 of the Set 2 | daan
# Processing Record 5 of the Set 2 | karaul
# City not found. Skipping...
# Processing Record 6 of the Set 2 | port alfred
# Processing Record 7 of the Set 2 | saskylakh
# City not found. Skipping...
# Processing Record 8 of the Set 2 | arraial do cabo
# Processing Record 9 of the Set 2 | faya
# Processing Record 10 of the Set 2 | kholm
# City not found. Skipping...
# Processing Record 11 of the Set 2 | liverpool
# Processing Record 12 of the Set 2 | college
# Processing Record 13 of the Set 2 | luderitz
# Processing Record 14 of the Set 2 | beloha
# City not found. Skipping...
# Processing Record 15 of the Set 2 | castro
# Processing Record 16 of the Set 2 | illoqqortoormiut
# Processing Record 17 of the Set 2 | gland
# Processing Record 18 of the Set 2 | mumford
# Processing Record 19 of the Set 2 | chiantla
# Processing Record 20 of the Set 2 | ilulissat
# Processing Record 21 of the Set 2 | oksfjord
# Processing Record 22 of the Set 2 | longyearbyen
# City not found. Skipping...
# Processing Record 23 of the Set 2 | upernavik
# Processing Record 24 of the Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 25 of the Set 2 | umzimvubu
# Processing Record 26 of the Set 2 | ushuaia
# Processing Record 27 of the Set 2 | cabo san lucas
# City not found. Skipping...
# Processing Record 28 of the Set 2 | san pedro
# Processing Record 29 of the Set 2 | barrow
# Processing Record 30 of the Set 2 | gubkinskiy
# City not found. Skipping...
# Processing Record 31 of the Set 2 | bredasdorp
# Processing Record 32 of the Set 2 | port elizabeth
# Processing Record 33 of the Set 2 | la reforma
# City not found. Skipping...
# Processing Record 34 of the Set 2 | alotau
# City not found. Skipping...
# Processing Record 35 of the Set 2 | tuktoyaktuk
# Processing Record 36 of the Set 2 | ozernovskiy
# City not found. Skipping...
# Processing Record 37 of the Set 2 | ceres
# Processing Record 38 of the Set 2 | isangel
# Processing Record 39 of the Set 2 | pangnirtung
# Processing Record 40 of the Set 2 | tonota
# Processing Record 41 of the Set 2 | port blair
# Processing Record 42 of the Set 2 | butaritari
# Processing Record 43 of the Set 2 | norman wells
# Processing Record 44 of the Set 2 | paamiut
# Processing Record 45 of the Set 2 | kysyl-syr
# City not found. Skipping...
# Processing Record 46 of the Set 2 | hermanus
# Processing Record 47 of the Set 2 | tasiilaq
# Processing Record 48 of the Set 2 | xichang
# Processing Record 49 of the Set 2 | srinagar
# Processing Record 50 of the Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 1 of the Set 3 | sakaiminato
# Processing Record 2 of the Set 3 | chumikan
# City not found. Skipping...
# Processing Record 3 of the Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of the Set 3 | ponta do sol
# Processing Record 5 of the Set 3 | sergiyevsk
# City not found. Skipping...
# Processing Record 6 of the Set 3 | esparta
# Processing Record 7 of the Set 3 | kamenka
# City not found. Skipping...
# Processing Record 8 of the Set 3 | mahebourg
# City not found. Skipping...
# Processing Record 9 of the Set 3 | atuona
# Processing Record 10 of the Set 3 | coquimbo
# Processing Record 11 of the Set 3 | pedernales
# Processing Record 12 of the Set 3 | bartica
# Processing Record 13 of the Set 3 | lavrentiya
# City not found. Skipping...
# Processing Record 14 of the Set 3 | tagusao
# Processing Record 15 of the Set 3 | labutta
# City not found. Skipping...
# Processing Record 16 of the Set 3 | pacific grove
# Processing Record 17 of the Set 3 | esperance
# Processing Record 18 of the Set 3 | araouane
# Processing Record 19 of the Set 3 | ribeira grande
# Processing Record 20 of the Set 3 | banes
# Processing Record 21 of the Set 3 | manokwari
# Processing Record 22 of the Set 3 | dikson
# City not found. Skipping...
# Processing Record 23 of the Set 3 | lolua
# Processing Record 24 of the Set 3 | lagos
# Processing Record 25 of the Set 3 | hokitika
# Processing Record 26 of the Set 3 | kavadarci
# Processing Record 27 of the Set 3 | ust-tsilma
# City not found. Skipping...
# Processing Record 28 of the Set 3 | riyadh
# Processing Record 29 of the Set 3 | cumpas
# City not found. Skipping...
# Processing Record 30 of the Set 3 | khani
# City not found. Skipping...
# Processing Record 31 of the Set 3 | los llanos de aridane
# Processing Record 32 of the Set 3 | cabedelo
# Processing Record 33 of the Set 3 | bourne
# Processing Record 34 of the Set 3 | hobart
# Processing Record 35 of the Set 3 | matara
# Processing Record 36 of the Set 3 | avera
# Processing Record 37 of the Set 3 | urumqi
# Processing Record 38 of the Set 3 | erenhot
# Processing Record 39 of the Set 3 | sorland
# Processing Record 40 of the Set 3 | kyra
# City not found. Skipping...
# Processing Record 41 of the Set 3 | hengshui
# Processing Record 42 of the Set 3 | hofn
# Processing Record 43 of the Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of the Set 3 | saint-pierre
# Processing Record 45 of the Set 3 | svetlyy
# City not found. Skipping...
# Processing Record 46 of the Set 3 | puerto colombia
# Processing Record 47 of the Set 3 | santa fe
# Processing Record 48 of the Set 3 | winnemucca
# Processing Record 49 of the Set 3 | pisco
# Processing Record 50 of the Set 3 | chegutu
# Processing Record 1 of the Set 4 | katsuura
# Processing Record 2 of the Set 4 | sorvag
# City not found. Skipping...
# Processing Record 3 of the Set 4 | sungairaya
# Processing Record 4 of the Set 4 | port macquarie
# Processing Record 5 of the Set 4 | ostrovnoy
# City not found. Skipping...
# Processing Record 6 of the Set 4 | huarmey
# Processing Record 7 of the Set 4 | tandalti
# Processing Record 8 of the Set 4 | gazanjyk
# Processing Record 9 of the Set 4 | lebu
# Processing Record 10 of the Set 4 | pitsunda
# Processing Record 11 of the Set 4 | pine bluff
# Processing Record 12 of the Set 4 | cruz grande
# City not found. Skipping...
# Processing Record 13 of the Set 4 | rungata
# Processing Record 14 of the Set 4 | hovd
# Processing Record 15 of the Set 4 | qaanaaq
# Processing Record 16 of the Set 4 | potsdam
# Processing Record 17 of the Set 4 | thompson
# Processing Record 18 of the Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 19 of the Set 4 | broome
# Processing Record 20 of the Set 4 | lorengau
# City not found. Skipping...
# Processing Record 21 of the Set 4 | provideniya
# City not found. Skipping...
# Processing Record 22 of the Set 4 | sao joao da barra
# Processing Record 23 of the Set 4 | ternate
# Processing Record 24 of the Set 4 | hornepayne
# Processing Record 25 of the Set 4 | geraldton
# Processing Record 26 of the Set 4 | slave lake
# Processing Record 27 of the Set 4 | rudbar
# Processing Record 28 of the Set 4 | kahului
# Processing Record 29 of the Set 4 | khatanga
# City not found. Skipping...
# Processing Record 30 of the Set 4 | torbay
# Processing Record 31 of the Set 4 | aykhal
# City not found. Skipping...
# Processing Record 32 of the Set 4 | leningradskiy
# City not found. Skipping...
# Processing Record 33 of the Set 4 | boende
# Processing Record 34 of the Set 4 | inhambane
# Processing Record 35 of the Set 4 | samarai
# City not found. Skipping...
# Processing Record 36 of the Set 4 | birecik
# Processing Record 37 of the Set 4 | miedzyrzec podlaski
# Processing Record 38 of the Set 4 | shenkursk
# City not found. Skipping...
# Processing Record 39 of the Set 4 | faanui
# Processing Record 40 of the Set 4 | mount isa
# Processing Record 41 of the Set 4 | merauke
# Processing Record 42 of the Set 4 | zhezkazgan
# Processing Record 43 of the Set 4 | havoysund
# Processing Record 44 of the Set 4 | dubti
# Processing Record 45 of the Set 4 | villaviciosa
# Processing Record 46 of the Set 4 | aleksandrov gay
# City not found. Skipping...
# Processing Record 47 of the Set 4 | zhigansk
# City not found. Skipping...
# Processing Record 48 of the Set 4 | tiksi
# City not found. Skipping...
# Processing Record 49 of the Set 4 | ancud
# Processing Record 50 of the Set 4 | atherton
# Processing Record 1 of the Set 5 | kuche
# Processing Record 2 of the Set 5 | vernon
# Processing Record 3 of the Set 5 | ust-kuyga
# City not found. Skipping...
# Processing Record 4 of the Set 5 | barra patuca
# Processing Record 5 of the Set 5 | morondava
# City not found. Skipping...
# Processing Record 6 of the Set 5 | agadez
# Processing Record 7 of the Set 5 | lago da pedra
# Processing Record 8 of the Set 5 | dali
# Processing Record 9 of the Set 5 | oro valley
# Processing Record 10 of the Set 5 | jamestown
# Processing Record 11 of the Set 5 | komsomolskiy
# City not found. Skipping...
# Processing Record 12 of the Set 5 | iqaluit
# Processing Record 13 of the Set 5 | makakilo city
# Processing Record 14 of the Set 5 | fairbanks
# Processing Record 15 of the Set 5 | kavieng
# City not found. Skipping...
# Processing Record 16 of the Set 5 | northam
# Processing Record 17 of the Set 5 | ganzhou
# Processing Record 18 of the Set 5 | portland
# Processing Record 19 of the Set 5 | aki
# Processing Record 20 of the Set 5 | srednekolymsk
# City not found. Skipping...
# Processing Record 21 of the Set 5 | husavik
# Processing Record 22 of the Set 5 | oga
# Processing Record 23 of the Set 5 | berdigestyakh
# City not found. Skipping...
# Processing Record 24 of the Set 5 | zyryanovsk
# Processing Record 25 of the Set 5 | cherskiy
# City not found. Skipping...
# Processing Record 26 of the Set 5 | emerald
# Processing Record 27 of the Set 5 | bako
# Processing Record 28 of the Set 5 | saleaula
# City not found. Skipping...
# Processing Record 29 of the Set 5 | inirida
# Processing Record 30 of the Set 5 | shimoda
# Processing Record 31 of the Set 5 | cockburn town
# Processing Record 32 of the Set 5 | sasykoli
# City not found. Skipping...
# Processing Record 33 of the Set 5 | ondorhaan
# Processing Record 34 of the Set 5 | union
# Processing Record 35 of the Set 5 | harper
# Processing Record 36 of the Set 5 | vao
# Processing Record 37 of the Set 5 | maceio
# Processing Record 38 of the Set 5 | malartic
# Processing Record 39 of the Set 5 | chagda
# City not found. Skipping...
# Processing Record 40 of the Set 5 | severo-kurilsk
# City not found. Skipping...
# Processing Record 41 of the Set 5 | dmitrovsk-orlovskiy
# City not found. Skipping...
# Processing Record 42 of the Set 5 | amderma
# City not found. Skipping...
# Processing Record 43 of the Set 5 | kathu
# Processing Record 44 of the Set 5 | sobolevo
# City not found. Skipping...
# Processing Record 45 of the Set 5 | pangai
# Processing Record 46 of the Set 5 | port lincoln
# Processing Record 47 of the Set 5 | avarua
# Processing Record 48 of the Set 5 | orlik
# City not found. Skipping...
# Processing Record 49 of the Set 5 | bereda
# Processing Record 50 of the Set 5 | sterling
# Processing Record 1 of the Set 6 | hithadhoo
# Processing Record 2 of the Set 6 | nhulunbuy
# Processing Record 3 of the Set 6 | biak
# Processing Record 4 of the Set 6 | wairoa
# Processing Record 5 of the Set 6 | dawei
# City not found. Skipping...
# Processing Record 6 of the Set 6 | cayenne
# Processing Record 7 of the Set 6 | jalingo
# Processing Record 8 of the Set 6 | skjervoy
# Processing Record 9 of the Set 6 | oxford
# Processing Record 10 of the Set 6 | ngukurr
# Processing Record 11 of the Set 6 | syamzha
# City not found. Skipping...
# Processing Record 12 of the Set 6 | bethel
# Processing Record 13 of the Set 6 | catalina
# Processing Record 14 of the Set 6 | mastic beach
# Processing Record 15 of the Set 6 | waitara
# Processing Record 16 of the Set 6 | coihaique
# Processing Record 17 of the Set 6 | coxim
# Processing Record 18 of the Set 6 | mega
# Processing Record 19 of the Set 6 | grand-santi
# Processing Record 20 of the Set 6 | mudyuga
# City not found. Skipping...
# Processing Record 21 of the Set 6 | san cristobal
# Processing Record 22 of the Set 6 | marsabit
# Processing Record 23 of the Set 6 | mayo
# Processing Record 24 of the Set 6 | warragul
# Processing Record 25 of the Set 6 | fare
# Processing Record 26 of the Set 6 | cangzhou
# Processing Record 27 of the Set 6 | attawapiskat
# Processing Record 28 of the Set 6 | grand gaube
# City not found. Skipping...
# Processing Record 29 of the Set 6 | wonthaggi
# Processing Record 30 of the Set 6 | mar del plata
# Processing Record 31 of the Set 6 | batagay
# City not found. Skipping...
# Processing Record 32 of the Set 6 | barcelos
# Processing Record 33 of the Set 6 | general roca
# Processing Record 34 of the Set 6 | plock
# Processing Record 35 of the Set 6 | shchelyayur
# City not found. Skipping...
# Processing Record 36 of the Set 6 | chokwe
# Processing Record 37 of the Set 6 | jos
# Processing Record 38 of the Set 6 | tromso
# Processing Record 39 of the Set 6 | puerto ayora
# Processing Record 40 of the Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 41 of the Set 6 | porto walter
# Processing Record 42 of the Set 6 | souillac
# City not found. Skipping...
# Processing Record 43 of the Set 6 | adelaide
# Processing Record 44 of the Set 6 | obihiro
# Processing Record 45 of the Set 6 | progreso
# City not found. Skipping...
# Processing Record 46 of the Set 6 | bilibino
# City not found. Skipping...
# Processing Record 47 of the Set 6 | yaan
# Processing Record 48 of the Set 6 | san patricio
# City not found. Skipping...
# Processing Record 49 of the Set 6 | diego de almagro
# Processing Record 50 of the Set 6 | hualmay
# Processing Record 1 of the Set 7 | caravelas
# Processing Record 2 of the Set 7 | lannion
# Processing Record 3 of the Set 7 | athabasca
# Processing Record 4 of the Set 7 | arman
# City not found. Skipping...
# Processing Record 5 of the Set 7 | chuy
# Processing Record 6 of the Set 7 | peace river
# Processing Record 7 of the Set 7 | saint-joseph
# Processing Record 8 of the Set 7 | clyde river
# Processing Record 9 of the Set 7 | kamina
# Processing Record 10 of the Set 7 | chingola
# Processing Record 11 of the Set 7 | guerrero negro
# City not found. Skipping...
# Processing Record 12 of the Set 7 | natal
# Processing Record 13 of the Set 7 | iroquois
# Processing Record 14 of the Set 7 | hobyo
# Processing Record 15 of the Set 7 | chokurdakh
# City not found. Skipping...
# Processing Record 16 of the Set 7 | thunder bay
# Processing Record 17 of the Set 7 | bentiu
# Processing Record 18 of the Set 7 | deputatskiy
# City not found. Skipping...
# Processing Record 19 of the Set 7 | vytegra
# City not found. Skipping...
# Processing Record 20 of the Set 7 | nemuro
# Processing Record 21 of the Set 7 | acarau
# Processing Record 22 of the Set 7 | recke
# Processing Record 23 of the Set 7 | ndele
# Processing Record 24 of the Set 7 | ouadda
# Processing Record 25 of the Set 7 | brawley
# Processing Record 26 of the Set 7 | huron
# Processing Record 27 of the Set 7 | baykit
# City not found. Skipping...
# Processing Record 28 of the Set 7 | misratah
# Processing Record 29 of the Set 7 | waipawa
# Processing Record 30 of the Set 7 | cidreira
# Processing Record 31 of the Set 7 | halalo
# City not found. Skipping...
# Processing Record 32 of the Set 7 | laguna
# Processing Record 33 of the Set 7 | sao lourenco da mata
# Processing Record 34 of the Set 7 | te anau
# Processing Record 35 of the Set 7 | cerrito
# Processing Record 36 of the Set 7 | hamilton
# Processing Record 37 of the Set 7 | erzin
# City not found. Skipping...
# Processing Record 38 of the Set 7 | kekri
# Processing Record 39 of the Set 7 | kichera
# City not found. Skipping...
# Processing Record 40 of the Set 7 | dunedin
# Processing Record 41 of the Set 7 | gemena
# Processing Record 42 of the Set 7 | bay saint louis
# Processing Record 43 of the Set 7 | kulevcha
# Processing Record 44 of the Set 7 | vila velha
# Processing Record 45 of the Set 7 | mirnyy
# City not found. Skipping...
# Processing Record 46 of the Set 7 | pietermaritzburg
# Processing Record 47 of the Set 7 | puerto leguizamo
# Processing Record 48 of the Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 49 of the Set 7 | ahuimanu
# Processing Record 50 of the Set 7 | saint george
# Processing Record 1 of the Set 8 | beringovskiy
# City not found. Skipping...
# Processing Record 2 of the Set 8 | fortuna
# Processing Record 3 of the Set 8 | airai
# Processing Record 4 of the Set 8 | nguiu
# Processing Record 5 of the Set 8 | marcona
# Processing Record 6 of the Set 8 | lagoa
# Processing Record 7 of the Set 8 | kuching
# Processing Record 8 of the Set 8 | mahon
# Processing Record 9 of the Set 8 | fort-shevchenko
# Processing Record 10 of the Set 8 | mangrol
# Processing Record 11 of the Set 8 | macaboboni
# Processing Record 12 of the Set 8 | linxia
# Processing Record 13 of the Set 8 | yialos
# City not found. Skipping...
# Processing Record 14 of the Set 8 | tura
# City not found. Skipping...
# Processing Record 15 of the Set 8 | lososina
# City not found. Skipping...
# Processing Record 16 of the Set 8 | nisia floresta
# Processing Record 17 of the Set 8 | pevek
# City not found. Skipping...
# Processing Record 18 of the Set 8 | ahipara
# Processing Record 19 of the Set 8 | port hardy
# Processing Record 20 of the Set 8 | dolores
# Processing Record 21 of the Set 8 | gorontalo
# Processing Record 22 of the Set 8 | teguldet
# City not found. Skipping...
# Processing Record 23 of the Set 8 | tual
# Processing Record 24 of the Set 8 | bonfim
# Processing Record 25 of the Set 8 | thinadhoo
# Processing Record 26 of the Set 8 | russell
# Processing Record 27 of the Set 8 | the hammocks
# Processing Record 28 of the Set 8 | belyy yar
# City not found. Skipping...
# Processing Record 29 of the Set 8 | nizhniy lomov
# City not found. Skipping...
# Processing Record 30 of the Set 8 | gusau
# Processing Record 31 of the Set 8 | sur
# Processing Record 32 of the Set 8 | kyaikto
# City not found. Skipping...
# Processing Record 33 of the Set 8 | witbank
# Processing Record 34 of the Set 8 | onokhoy
# City not found. Skipping...
# Processing Record 35 of the Set 8 | pimenta bueno
# Processing Record 36 of the Set 8 | beni
# Processing Record 37 of the Set 8 | oulu
# Processing Record 38 of the Set 8 | bandar-e torkaman
# Processing Record 39 of the Set 8 | altay
# Processing Record 40 of the Set 8 | georgetown
# Processing Record 41 of the Set 8 | norden
# Processing Record 42 of the Set 8 | shache
# Processing Record 43 of the Set 8 | talnakh
# City not found. Skipping...
# Processing Record 44 of the Set 8 | yulara
# Processing Record 45 of the Set 8 | alofi
# Processing Record 46 of the Set 8 | kulebaki
# City not found. Skipping...
# Processing Record 47 of the Set 8 | namtsy
# City not found. Skipping...
# Processing Record 48 of the Set 8 | amulung
# Processing Record 49 of the Set 8 | issoire
# Processing Record 50 of the Set 8 | vestmanna
# City not found. Skipping...
# Processing Record 1 of the Set 9 | the valley
# Processing Record 2 of the Set 9 | ayan
# City not found. Skipping...
# Processing Record 3 of the Set 9 | satitoa
# City not found. Skipping...
# Processing Record 4 of the Set 9 | llangefni
# Processing Record 5 of the Set 9 | saint-jean-port-joli
# Processing Record 6 of the Set 9 | forio
# Processing Record 7 of the Set 9 | uberlandia
# Processing Record 8 of the Set 9 | tarancon
# Processing Record 9 of the Set 9 | copiapo
# Processing Record 10 of the Set 9 | lang son
# Processing Record 11 of the Set 9 | bailen
# Processing Record 12 of the Set 9 | gander
# Processing Record 13 of the Set 9 | wageningen
# Processing Record 14 of the Set 9 | mahibadhoo
# Processing Record 15 of the Set 9 | tungkang
# City not found. Skipping...
# Processing Record 16 of the Set 9 | apricena
# Processing Record 17 of the Set 9 | toliary
# City not found. Skipping...
# Processing Record 18 of the Set 9 | amga
# City not found. Skipping...
# Processing Record 19 of the Set 9 | ratnagiri
# Processing Record 20 of the Set 9 | abu samrah
# Processing Record 21 of the Set 9 | dudinka
# City not found. Skipping...
# Processing Record 22 of the Set 9 | egvekinot
# City not found. Skipping...
# Processing Record 23 of the Set 9 | muroto
# Processing Record 24 of the Set 9 | narsaq
# Processing Record 25 of the Set 9 | healdsburg
# Processing Record 26 of the Set 9 | port moresby
# City not found. Skipping...
# Processing Record 27 of the Set 9 | dajal
# Processing Record 28 of the Set 9 | pierre
# Processing Record 29 of the Set 9 | zabolottya
# Processing Record 30 of the Set 9 | victoria
# Processing Record 31 of the Set 9 | whitehaven
# Processing Record 32 of the Set 9 | okhotsk
# City not found. Skipping...
# Processing Record 33 of the Set 9 | tezu
# Processing Record 34 of the Set 9 | cap malheureux
# City not found. Skipping...
# Processing Record 35 of the Set 9 | wanning
# Processing Record 36 of the Set 9 | monte alegre
# Processing Record 37 of the Set 9 | ambovombe
# City not found. Skipping...
# Processing Record 38 of the Set 9 | tambovka
# City not found. Skipping...
# Processing Record 39 of the Set 9 | codrington
# Processing Record 40 of the Set 9 | vardo
# Processing Record 41 of the Set 9 | port keats
# Processing Record 42 of the Set 9 | belaya gora
# City not found. Skipping...
# Processing Record 43 of the Set 9 | sao filipe
# Processing Record 44 of the Set 9 | banda aceh
# Processing Record 45 of the Set 9 | sangar
# City not found. Skipping...
# Processing Record 46 of the Set 9 | bouna
# Processing Record 47 of the Set 9 | santa ana de yusguare
# Processing Record 48 of the Set 9 | novokayakent
# City not found. Skipping...
# Processing Record 49 of the Set 9 | marawi
# Processing Record 50 of the Set 9 | wuda
# Processing Record 1 of the Set 10 | rio grande
# Processing Record 2 of the Set 10 | tasbuget
# Processing Record 3 of the Set 10 | ewa beach
# Processing Record 4 of the Set 10 | tarko-sale
# City not found. Skipping...
# Processing Record 5 of the Set 10 | phrai bung
# Processing Record 6 of the Set 10 | aklavik
# Processing Record 7 of the Set 10 | samusu
# City not found. Skipping...
# Processing Record 8 of the Set 10 | kabul
# Processing Record 9 of the Set 10 | haines junction
# Processing Record 10 of the Set 10 | ust-kulom
# City not found. Skipping...
# Processing Record 11 of the Set 10 | tallahassee
# Processing Record 12 of the Set 10 | leeuwarden
# Processing Record 13 of the Set 10 | gushikawa
# Processing Record 14 of the Set 10 | sungai petani
# Processing Record 15 of the Set 10 | mackay
# Processing Record 16 of the Set 10 | kapiri mposhi
# Processing Record 17 of the Set 10 | barmer
# Processing Record 18 of the Set 10 | rairangpur
# Processing Record 19 of the Set 10 | salalah
# Processing Record 20 of the Set 10 | bandarbeyla
# Processing Record 21 of the Set 10 | morehead
# City not found. Skipping...
# Processing Record 22 of the Set 10 | tawzar
# City not found. Skipping...
# Processing Record 23 of the Set 10 | atambua
# Processing Record 24 of the Set 10 | villacarrillo
# Processing Record 25 of the Set 10 | touros
# Processing Record 26 of the Set 10 | lock haven
# Processing Record 27 of the Set 10 | udala
# Processing Record 28 of the Set 10 | minden
# Processing Record 29 of the Set 10 | dolbeau
# Processing Record 30 of the Set 10 | hammerfest
# Processing Record 31 of the Set 10 | teya
# City not found. Skipping...
# Processing Record 32 of the Set 10 | shizunai
# Processing Record 33 of the Set 10 | zyryanka
# City not found. Skipping...
# Processing Record 34 of the Set 10 | bathsheba
# Processing Record 35 of the Set 10 | broken hill
# Processing Record 36 of the Set 10 | wetzlar
# Processing Record 37 of the Set 10 | mubende
# Processing Record 38 of the Set 10 | namibe
# Processing Record 39 of the Set 10 | tarusa
# City not found. Skipping...
# Processing Record 40 of the Set 10 | newburgh
# Processing Record 41 of the Set 10 | jalu
# Processing Record 42 of the Set 10 | gallup
# Processing Record 43 of the Set 10 | rosario
# Processing Record 44 of the Set 10 | wundanyi
# Processing Record 45 of the Set 10 | saint-philippe
# Processing Record 46 of the Set 10 | wenling
# Processing Record 47 of the Set 10 | southbridge
# Processing Record 48 of the Set 10 | iralaya
# Processing Record 49 of the Set 10 | gazojak
# Processing Record 50 of the Set 10 | saldanha
# Processing Record 1 of the Set 11 | nantucket
# Processing Record 2 of the Set 11 | sakhon nakhon
# Processing Record 3 of the Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 4 of the Set 11 | mogocha
# City not found. Skipping...
# Processing Record 5 of the Set 11 | wewak
# City not found. Skipping...
# Processing Record 6 of the Set 11 | iguape
# Processing Record 7 of the Set 11 | west wendover
# Processing Record 8 of the Set 11 | gulshat
# Processing Record 9 of the Set 11 | okha
# City not found. Skipping...
# Processing Record 10 of the Set 11 | rochegda
# City not found. Skipping...
# Processing Record 11 of the Set 11 | alta floresta
# Processing Record 12 of the Set 11 | salinas
# City not found. Skipping...
# Processing Record 13 of the Set 11 | kaputa
# Processing Record 14 of the Set 11 | omboue
# Processing Record 15 of the Set 11 | aranos
# Processing Record 16 of the Set 11 | atar
# Processing Record 17 of the Set 11 | paracelis
# Processing Record 18 of the Set 11 | kailua
# Processing Record 19 of the Set 11 | mehamn
# Processing Record 20 of the Set 11 | presidente medici
# Processing Record 21 of the Set 11 | elko
# Processing Record 22 of the Set 11 | leeton
# Processing Record 23 of the Set 11 | ponta do sol
# Processing Record 24 of the Set 11 | komatipoort
# Processing Record 25 of the Set 11 | tsogni
# Processing Record 26 of the Set 11 | sao goncalo do sapucai
# Processing Record 27 of the Set 11 | kroonstad
# Processing Record 28 of the Set 11 | durango
# Processing Record 29 of the Set 11 | palmer
# Processing Record 30 of the Set 11 | ladario
# Processing Record 31 of the Set 11 | dillon
# Processing Record 32 of the Set 11 | buluang
# Processing Record 33 of the Set 11 | zhireken
# City not found. Skipping...
# Processing Record 34 of the Set 11 | texarkana
# Processing Record 35 of the Set 11 | arica
# Processing Record 36 of the Set 11 | katangi
# Processing Record 37 of the Set 11 | dzaoudzi
# Processing Record 38 of the Set 11 | camocim
# Processing Record 39 of the Set 11 | batagay-alyta
# City not found. Skipping...
# Processing Record 40 of the Set 11 | ryotsu
# Processing Record 41 of the Set 11 | sweetwater
# Processing Record 42 of the Set 11 | awjilah
# Processing Record 43 of the Set 11 | nioro
# Processing Record 44 of the Set 11 | kolyvan
# City not found. Skipping...
# Processing Record 45 of the Set 11 | north branch
# Processing Record 46 of the Set 11 | tam ky
# Processing Record 47 of the Set 11 | moussoro
# Processing Record 48 of the Set 11 | kutum
# Processing Record 49 of the Set 11 | bowen
# Processing Record 50 of the Set 11 | whitehorse
# Processing Record 1 of the Set 12 | tyup
# Processing Record 2 of the Set 12 | verkhnevilyuysk
# City not found. Skipping...
# Processing Record 3 of the Set 12 | koslan
# City not found. Skipping...
# Processing Record 4 of the Set 12 | ecija
# Processing Record 5 of the Set 12 | nelidovo
# City not found. Skipping...
# Processing Record 6 of the Set 12 | umm kaddadah
# Processing Record 7 of the Set 12 | iberia
# Processing Record 8 of the Set 12 | san lorenzo
# Processing Record 9 of the Set 12 | brae
# Processing Record 10 of the Set 12 | atlantic beach
# Processing Record 11 of the Set 12 | kalomo
# Processing Record 12 of the Set 12 | hami
# Processing Record 13 of the Set 12 | amahai
# Processing Record 14 of the Set 12 | leshukonskoye
# City not found. Skipping...
# Processing Record 15 of the Set 12 | klyuchi
# City not found. Skipping...
# Processing Record 16 of the Set 12 | lompoc
# Processing Record 17 of the Set 12 | gouyave
# Processing Record 18 of the Set 12 | gorele
# Processing Record 19 of the Set 12 | benguela
# Processing Record 20 of the Set 12 | bathurst
# Processing Record 21 of the Set 12 | shihezi
# Processing Record 22 of the Set 12 | alegrete
# Processing Record 23 of the Set 12 | rosarito
# City not found. Skipping...
# Processing Record 24 of the Set 12 | bengkulu
# Processing Record 25 of the Set 12 | kapit
# Processing Record 26 of the Set 12 | ust-barguzin
# City not found. Skipping...
# Processing Record 27 of the Set 12 | padampur
# Processing Record 28 of the Set 12 | bonoua
# Processing Record 29 of the Set 12 | burnie
# Processing Record 30 of the Set 12 | la ronge
# Processing Record 31 of the Set 12 | liniere
# Processing Record 32 of the Set 12 | preobrazheniye
# City not found. Skipping...
# Processing Record 33 of the Set 12 | puerto carreno
# Processing Record 34 of the Set 12 | queenstown
# Processing Record 35 of the Set 12 | caucaia
# Processing Record 36 of the Set 12 | richards bay
# Processing Record 37 of the Set 12 | tanhacu
# Processing Record 38 of the Set 12 | port hedland
# Processing Record 39 of the Set 12 | vila franca do campo
# Processing Record 40 of the Set 12 | shahrud
# Processing Record 41 of the Set 12 | meulaboh
# Processing Record 42 of the Set 12 | blind river
# Processing Record 43 of the Set 12 | salinopolis
# Processing Record 44 of the Set 12 | yar-sale
# City not found. Skipping...
# Processing Record 45 of the Set 12 | porto belo
# Processing Record 46 of the Set 12 | port hueneme
# Processing Record 47 of the Set 12 | ayolas
# Processing Record 48 of the Set 12 | henties bay
# Processing Record 49 of the Set 12 | lithakia
# City not found. Skipping...
# Processing Record 50 of the Set 12 | baljevac
# Processing Record 1 of the Set 13 | brownwood
# Processing Record 2 of the Set 13 | pangody
# City not found. Skipping...
# Processing Record 3 of the Set 13 | sorsk
# City not found. Skipping...
# Processing Record 4 of the Set 13 | pouembout
# Processing Record 5 of the Set 13 | arroyo
# Processing Record 6 of the Set 13 | nishihara
# Processing Record 7 of the Set 13 | namalenga
# Processing Record 8 of the Set 13 | chortkiv
# Processing Record 9 of the Set 13 | kaitangata
# Processing Record 10 of the Set 13 | vostok
# City not found. Skipping...
# Processing Record 11 of the Set 13 | kloulklubed
# Processing Record 12 of the Set 13 | semey
# Processing Record 13 of the Set 13 | poya
# Processing Record 14 of the Set 13 | johnstown
# Processing Record 15 of the Set 13 | nabire
# Processing Record 16 of the Set 13 | dire dawa
# Processing Record 17 of the Set 13 | dingle
# Processing Record 18 of the Set 13 | poli
# Processing Record 19 of the Set 13 | rognan
# Processing Record 20 of the Set 13 | saint anthony
# Processing Record 21 of the Set 13 | marsaxlokk
# Processing Record 22 of the Set 13 | upata
# Processing Record 23 of the Set 13 | pitimbu
# Processing Record 24 of the Set 13 | myitkyina
# City not found. Skipping...
# Processing Record 25 of the Set 13 | prachuap khiri khan
# Processing Record 26 of the Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 27 of the Set 13 | saint-augustin
# Processing Record 28 of the Set 13 | bud
# Processing Record 29 of the Set 13 | izhma
# City not found. Skipping...
# Processing Record 30 of the Set 13 | bubaque
# Processing Record 31 of the Set 13 | kodinsk
# City not found. Skipping...
# Processing Record 32 of the Set 13 | roald
# Processing Record 33 of the Set 13 | inderborskiy
# Processing Record 34 of the Set 13 | amuntai
# Processing Record 35 of the Set 13 | san juan de colon
# Processing Record 36 of the Set 13 | santa vitoria do palmar
# Processing Record 37 of the Set 13 | plettenberg bay
# Processing Record 38 of the Set 13 | fortuna foothills
# Processing Record 39 of the Set 13 | salamanca
# Processing Record 40 of the Set 13 | dukat
# City not found. Skipping...
# Processing Record 41 of the Set 13 | marsberg
# Processing Record 42 of the Set 13 | vangaindrano
# City not found. Skipping...
# Processing Record 43 of the Set 13 | namatanai
# City not found. Skipping...
# Processing Record 44 of the Set 13 | gilgit
# Processing Record 45 of the Set 13 | ciechocinek
# Processing Record 46 of the Set 13 | borovskoy
# Processing Record 47 of the Set 13 | jiaozuo
# Processing Record 48 of the Set 13 | mola di bari
# Processing Record 49 of the Set 13 | miri
# Processing Record 50 of the Set 13 | kazalinsk
# Processing Record 1 of the Set 14 | todos santos
# City not found. Skipping...
# Processing Record 2 of the Set 14 | santa maria
# Processing Record 3 of the Set 14 | kitimat
# Processing Record 4 of the Set 14 | ola
# City not found. Skipping...
# Processing Record 5 of the Set 14 | carlsbad
# Processing Record 6 of the Set 14 | karamea
# Processing Record 7 of the Set 14 | peniche
# Processing Record 8 of the Set 14 | lebedinyy
# City not found. Skipping...
# Processing Record 9 of the Set 14 | steger
# Processing Record 10 of the Set 14 | tsukumi
# Processing Record 11 of the Set 14 | flinders
# Processing Record 12 of the Set 14 | huilong
# Processing Record 13 of the Set 14 | mitsamiouli
# City not found. Skipping...
# Processing Record 14 of the Set 14 | bemidji
# Processing Record 15 of the Set 14 | gravdal
# Processing Record 16 of the Set 14 | korhogo
# Processing Record 17 of the Set 14 | palabuhanratu
# Processing Record 18 of the Set 14 | manzhouli
# Processing Record 19 of the Set 14 | suntar
# City not found. Skipping...
# Processing Record 20 of the Set 14 | novyy urengoy
# City not found. Skipping...
# Processing Record 21 of the Set 14 | nagato
# Processing Record 22 of the Set 14 | hambantota
# Processing Record 23 of the Set 14 | san lorenzo
# Processing Record 24 of the Set 14 | moron
# Processing Record 25 of the Set 14 | klaksvik
# City not found. Skipping...
# Processing Record 26 of the Set 14 | jiwani
# Processing Record 27 of the Set 14 | lashio
# City not found. Skipping...
# Processing Record 28 of the Set 14 | bambui
# Processing Record 29 of the Set 14 | auala
# City not found. Skipping...
# Processing Record 30 of the Set 14 | mpulungu
# Processing Record 31 of the Set 14 | tortoli
# Processing Record 32 of the Set 14 | sol-iletsk
# City not found. Skipping...
# Processing Record 33 of the Set 14 | kupang
# Processing Record 34 of the Set 14 | abay
# Processing Record 35 of the Set 14 | demidov
# City not found. Skipping...
# Processing Record 36 of the Set 14 | ishigaki
# Processing Record 37 of the Set 14 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 38 of the Set 14 | kandrian
# City not found. Skipping...
# Processing Record 39 of the Set 14 | kieta
# City not found. Skipping...
# Processing Record 40 of the Set 14 | honningsvag
# Processing Record 41 of the Set 14 | phan rang
# Processing Record 42 of the Set 14 | lahat
# Processing Record 43 of the Set 14 | kijang
# Processing Record 44 of the Set 14 | moerai
# Processing Record 45 of the Set 14 | panguna
# City not found. Skipping...
# Processing Record 46 of the Set 14 | piacabucu
# Processing Record 47 of the Set 14 | corumba
# Processing Record 48 of the Set 14 | igbo ora
# Processing Record 49 of the Set 14 | necochea
# Processing Record 50 of the Set 14 | coahuayana
# City not found. Skipping...
# Processing Record 1 of the Set 15 | palapye
# Processing Record 2 of the Set 15 | wainwright
# Processing Record 3 of the Set 15 | rabo de peixe
# Processing Record 4 of the Set 15 | sarkand
# Processing Record 5 of the Set 15 | tabou
# Processing Record 6 of the Set 15 | malwan
# Processing Record 7 of the Set 15 | tabiauea
# Processing Record 8 of the Set 15 | cravo norte
# Processing Record 9 of the Set 15 | outlook
# Processing Record 10 of the Set 15 | ormara
# Processing Record 11 of the Set 15 | walvis bay
# Processing Record 12 of the Set 15 | tiznit
# Processing Record 13 of the Set 15 | half moon bay
# Processing Record 14 of the Set 15 | kurilsk
# City not found. Skipping...
# Processing Record 15 of the Set 15 | marrakesh
# Processing Record 16 of the Set 15 | robertsganj
# Processing Record 17 of the Set 15 | sao geraldo do araguaia
# Processing Record 18 of the Set 15 | poum
# Processing Record 19 of the Set 15 | adre
# Processing Record 20 of the Set 15 | abalak
# Processing Record 21 of the Set 15 | doka
# Processing Record 22 of the Set 15 | uaua
# Processing Record 23 of the Set 15 | praxedis guerrero
# City not found. Skipping...
# Processing Record 24 of the Set 15 | barstow
# Processing Record 25 of the Set 15 | fayaoue
# Processing Record 26 of the Set 15 | plymouth
# Processing Record 27 of the Set 15 | marzuq
# Processing Record 28 of the Set 15 | kenitra
# Processing Record 29 of the Set 15 | yumen
# Processing Record 30 of the Set 15 | sola
# Processing Record 31 of the Set 15 | ati
# Processing Record 32 of the Set 15 | hewitt
# Processing Record 33 of the Set 15 | novoagansk
# City not found. Skipping...
# Processing Record 34 of the Set 15 | seybaplaya
# City not found. Skipping...
# Processing Record 35 of the Set 15 | ilhabela
# Processing Record 36 of the Set 15 | talcahuano
# Processing Record 37 of the Set 15 | viedma
# Processing Record 38 of the Set 15 | formoso do araguaia
# Processing Record 39 of the Set 15 | oneonta
# Processing Record 40 of the Set 15 | olafsvik
# Processing Record 41 of the Set 15 | zaragoza
# Processing Record 42 of the Set 15 | noyabrsk
# City not found. Skipping...
# Processing Record 43 of the Set 15 | kandalaksha
# City not found. Skipping...
# Processing Record 44 of the Set 15 | lasa
# Processing Record 45 of the Set 15 | chapleau
# Processing Record 46 of the Set 15 | pella
# Processing Record 47 of the Set 15 | paradwip
# Processing Record 48 of the Set 15 | murdochville
# Processing Record 49 of the Set 15 | najran
# Processing Record 50 of the Set 15 | mingshui
# Processing Record 1 of the Set 16 | chiang khong
# Processing Record 2 of the Set 16 | usinsk
# City not found. Skipping...
# Processing Record 3 of the Set 16 | tuatapere
# Processing Record 4 of the Set 16 | cosamaloapan
# City not found. Skipping...
# Processing Record 5 of the Set 16 | katangli
# City not found. Skipping...
# Processing Record 6 of the Set 16 | takoradi
# Processing Record 7 of the Set 16 | camacupa
# Processing Record 8 of the Set 16 | tautira
# Processing Record 9 of the Set 16 | praia
# Processing Record 10 of the Set 16 | azul
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check numer of cities
len(city_data)
# Out:
# 580

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Kodiak      US  57.7900 -152.4072     38.71        75         100
# 1  Cape Town      ZA -33.9258   18.4232     60.28        69           0
# 2       Asau      RO  46.4333   26.4000     45.95        82         100
# 3     Katobu      ID  -4.9408  122.5276     74.79        93          85
# 4      Bluff      NZ -46.6000  168.3333     56.52        65          91
#
#    Wind Speed Current Description
# 0        6.91          light snow
# 1       20.71           clear sky
# 2        4.74     overcast clouds
# 3        1.54     overcast clouds
# 4       27.38     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
